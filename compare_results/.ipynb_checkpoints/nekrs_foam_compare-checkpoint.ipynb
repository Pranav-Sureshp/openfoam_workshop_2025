# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pandas as pd

# %%
nekrs_dir='/home/pranav/data/Nekrs_results/'
foam_dir='/home/pranav/data/OpenFOAM/MHD_IED/circular/u2B1.75_mesh2_copy/'

# %%
foam_data='u_profileY.csv'

nekrs_data ='u_x_outlet.csv';
un = 2.0

# %%
df = pd.read_csv(nekrs_dir+nekrs_data)

# %%
## Nekrs results
plt.figure(figsize=(8, 6))
plt.plot(df['Velocity:0']/2.0, df['Points:0'], linestyle='--', label='Nekrs results', linewidth=1.5)

# Labels and title with increased font size
plt.xlabel(r'$u_z$', fontsize=20)
plt.ylabel(r'$x$', fontsize=20)

plt.ylim([0,1])
# Add legend
plt.legend(fontsize=16)

# ------------
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df = pd.read_csv(foam_dir+foam_data)

# %%
df
# Out:
#      B0:0  B0:1  B0:2          J:0       J:1     J:2      PotE           U:0  \
# 0    1.75     0     0      -4.0488  276770.0  52.940 -0.076086  0.000000e+00
# 1    1.75     0     0      -3.0688  276960.0  53.615 -0.076086  3.290100e-08
# 2    1.75     0     0  -95116.0000  275260.0  55.807 -0.076076  4.099300e-08
# 3    1.75     0     0      -3.0693  277380.0  53.652 -0.076086  7.100600e-08
# 4    1.75     0     0  -93908.0000  275710.0  55.843 -0.076076  8.734600e-08
# ..    ...   ...   ...          ...       ...     ...       ...           ...
# 405  0.00     0     0       0.0000       0.0   0.000  0.000000  0.000000e+00
# 406  1.75     0     0       6.7310  277390.0 -81.902  0.076087  1.867000e-07
# 407  1.75     0     0   95126.0000  275270.0 -81.693  0.076077  1.086100e-07
# 408  1.75     0     0  190240.0000  273580.0 -81.421  0.076066  6.578300e-08
# 409  1.75     0     0  189310.0000  273430.0 -81.176  0.076066  0.000000e+00
#
# ...

# %%
## openfoam results
plt.figure(figsize=(8, 6))
plt.plot(df['U:2'], df['Points:1'], linestyle='--', label='Nekrs results')

# Labels and title with increased font size
plt.xlabel(r'$u_z$', fontsize=20)
plt.ylabel(r'$x$', fontsize=20)


# Add legend
plt.legend(fontsize=16)
